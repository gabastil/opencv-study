# %% [markdown]
# # TESSERACT OCR Study
# ---
# Glenn Abastillas

# %%
from pytesseract import image_to_data
from PIL import Image
from glob import glob

import PyPDF2
from pdf2image import convert_from_path

pdf = glob('../data/*.pdf')[0]
pdf
# Out:
# '../data/2020.04.12_Boletim_Epidemiologico_Diario_COVID19_N11_2020_04_12.pdf'

# %% [markdown]
# ## Load Data (PyPDF2)

# %%
data = PyPDF2.PdfFileReader(open(pdf, 'rb'))
page = data.getPage(0)
xObject = page['/Resources']['/XObject'].getObject()

# %% [markdown]
# Loop through xObject

# %%
images = []
for label in xObject:
    current = xObject[label]
    subtype = current['/Subtype']
    print(current)
    data = current.getData()
    
#     print(subtype)
    if subtype == '/Image':
        colortype = current['/ColorSpace']
        filter_ = current['/Filter']
        size = (current['/Width'], current['/Height'])
        
        if colortype == '/DeviceRGB':
            mode = 'RGB'
        else:
            mode = 'P'
        
        if filter_ == '/FlateDecode':
            image = Image.frombytes(mode, size, data)
            images.append(image)
#         elif filter_ == '/DCTDecode':
#             image = open(label[1:] + '.jpg', 'wb')
#             image.write(data)
#             images.append(image)
#             image.close()
#         print(colortype, filter_)
#     print(current.keys())
#     img = Image.open(current.getData(), mode='rb')
#     images.append(img)
#     print(img)
# Out:
# {'/Type': '/XObject', '/Subtype': '/Image', '/Width': 145, '/Height': 134, '/ColorSpace': '/DeviceRGB', '/BitsPerComponent': 8, '/Interpolate': <PyPDF2.generic.BooleanObject object at 0x12027cda0>, '/Filter': '/FlateDecode'}
# {'/Type': '/XObject', '/Subtype': '/Image', '/Width': 150, '/Height': 64, '/ColorSpace': '/DeviceRGB', '/BitsPerComponent': 8, '/Interpolate': <PyPDF2.generic.BooleanObject object at 0x12027c2b0>, '/SMask': IndirectObject(28, 0), '/Filter': '/FlateDecode'}
# {'/Type': '/XObject', '/Subtype': '/Image', '/Width': 237, '/Height': 120, '/ColorSpace': '/DeviceRGB', '/BitsPerComponent': 8, '/Filter': '/DCTDecode', '/Interpolate': <PyPDF2.generic.BooleanObject object at 0x12027c828>}
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-29-537611aa8a20> in <module>
#       4     subtype = current['/Subtype']
#       5     print(current)
# ----> 6     data = current.getData()
#       7
#       8 #     print(subtype)
#
# /Applications/anaconda/envs/mapping_env/lib/python3.7/site-packages/PyPDF2/generic.py in getData(self)
#     839             decoded = DecodedStreamObject()
#     840
# --> 841             decoded._data = filters.decodeStreamData(self)
#     842             for key, value in list(self.items()):
#     843                 if not key in ("/Length", "/Filter", "/DecodeParms"):
#
# /Applications/anaconda/envs/mapping_env/lib/python3.7/site-packages/PyPDF2/filters.py in decodeStreamData(stream)
#     359             else:
#     360                 # unsupported filter
# --> 361                 raise NotImplementedError("unsupported filter %s" % filterType)
#     362     return data
#
# NotImplementedError: unsupported filter /DCTDecode

# %%
image = convert_from_path(glob('../data/*.pdf')[0])

# %%
image[0]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x11FFD20B8>

# %% [markdown]
# `PyPDF2` superceded by `pdf2image`

# %%
# pdf = open(glob("../data/*.pdf")[0], 'rb')
# image = PyPDF2.PdfFileReader(pdf)

# %%
Image.open(bytes(image[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-b4d2c4eb2de3> in <module>
# ----> 1 Image.open(bytes(image[0]))
#
# TypeError: cannot convert 'PpmImageFile' object to bytes

# %% [markdown]
# ### Read Text

# %%
import pytesseract as ocr

# %%
image[0]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x11FFD20B8>

# %%
ocr.image_to_string(image[0]).split()
# Out:
# ['REPUBLICA',
#  'DA',
#  'Ministério',
#  'da',
#  'GD',
#  'ees',
#  '(OES',
#  '-',
#  'GB',
#  'Satide',
#  'Publica',
#  'Centra',
#  'be',
#  'Operacnes',
#  'de',
#  'tmergencis',
#  'em',
#  'Sande',
#  'de',
#  'Guine',
#  'Ben',
#  'GUINE-BISSAU',
#  '—',
#  'BOLETIM',
#  'EPIDEMIOLOGICO',
#  'N°11',
#  'COVID-19',
#  'DOENCA',
#  'PELO',
#  'CORONAVIRUS',
#  '2019',
#  'SUMARIO',
#  'Situacgdo',
#  'epidemioldgica',
#  'no',
#  'mundo',
#  '2',
#  'Situacgdo',
#  'epidemioldgica',
#  'na',
#  'Africa',
#  '2',
#  'Situacgdo',
#  'epidemioldgica',
#  'na',
#  'Guiné-Bissau',
#  '3',
#  'Sistema',
#  'de',
#  'Informagao',
#  'Sanitaria',
#  '(SIS)',
#  '3',
#  'COVID-19',
#  'DESTAQUES',
#  'Conforme',
#  'os',
#  'dados',
#  'da',
#  'Organizagao',
#  'Mundial',
#  'da',
#  'Satide,',
#  'a',
#  'nivel',
#  'mundial',
#  'ja',
#  'se',
#  'confirmaram',
#  '1.',
#  '610,909',
#  'casos',
#  'de',
#  'COVID-19',
#  'e',
#  '99.690',
#  'Obitos',
#  '(6.892',
#  'novos',
#  'dbitos).',
#  'Sendo',
#  'que',
#  'para',
#  'a',
#  'regiao',
#  'africana,',
#  'até',
#  'o',
#  'dia',
#  '10/04/2020',
#  'foram',
#  'confirmados',
#  '9.340',
#  'casos',
#  'de',
#  'COVID-19',
#  'e',
#  '415',
#  'Obitos.',
#  'Recomenda-se',
#  'a',
#  'toda',
#  'apopulagao',
#  'ocumprimento',
#  'das',
#  'medidas',
#  'de',
#  'protecao',
#  'disseminadas',
#  'pelo',
#  'Ministério',
#  'da',
#  'Saude',
#  'e',
#  'parceiros,',
#  'além',
#  'de',
#  'utilizar',
#  'alinha',
#  'directa',
#  'COVID-19',
#  '(1919',
#  '(MTN)/2020',
#  '(ORANGE)/966',
#  '050',
#  '002)',
#  'para',
#  'informacgdes',
#  'sobre',
#  'ovirus',
#  'e',
#  'relatar',
#  'algum',
#  'evento',
#  'ou',
#  'condigdes',
#  'de',
#  'satide.',
#  'Esta',
#  'linha',
#  'é',
#  'para',
#  'fins',
#  'de',
#  'emergéncia',
#  'e',
#  'deve',
#  'ser',
#  'utilizada',
#  'com',
#  'responsabilidade,',
#  'por',
#  'isso',
#  'apela-se',
#  'a',
#  'toda',
#  'populagao',
#  'que',
#  'evite',
#  'rumores',
#  'falsos',
#  'ou',
#  'brincadeiras.',
#  '12',
#  'de',
#  'Abril',
#  'de',
#  '2020']
